# %% [markdown]
# ## Data Ingestion

# %%
## Document structure 

from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "this is the main page content to learn RAG application",
    metadata = {
        "Source":'example application',
        "pages": 10,
        "Author":'Abdul',
        "Date_created":'22-07-26'
    }
)

# %%
doc
# Out:
# Document(metadata={'Source': 'example application', 'pages': 10, 'Author': 'Abdul', 'Date_created': '22-07-26'}, page_content='this is the main page content to learn RAG application')

# %%
pip install os
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
#create a simple txt file 

import os
os.makedirs("../data/text_file",exist_ok=True)

# %%
sample_texts = {
    "../data/text_file/python_intro.txt":"""python programming Introduction
    Python is a high-level, general-purpose programming language that has become one of the most popular languages in the world due to its simplicity and readability. 
    Created by Guido van Rossum and released in 1991, Python is designed to look much like the English language, making it an ideal choice for absolute beginners. [1] (https://www.w3schools.com/python/python_intro.asp), 
    [2] (https://www.geeksforgeeks.org/python/introduction-to-python/), 
    [3] (https://en.wikipedia.org/wiki/Python_(programming_language)), 
    [4] (https://www.youtube.com/watch?v=K5KVEU3aaeQ&t=1), 
    [5] (https://www.tutorialspoint.com/python/python_overview.htm)
    Key Features of PythonReadability: 
    Python uses clean formatting and relies on whitespace indentation instead of curly braces {} or semicolons to define blocks of code.
      [1] (https://www.geeksforgeeks.org/python/introduction-to-python/), 
      [2] (https://en.wikipedia.org/wiki/Python_(programming_language))Interpreted Language: Code is executed line-by-line as soon as it is written, allowing for rapid testing and prototyping. 
      [1] (https://www.w3schools.com/python/python_intro.asp), 
      [2] (https://www.tutorialspoint.com/python/python_overview.htm)
      Versatile Paradigms: It supports multiple programming styles, including procedural, object-oriented, and functional programming. 
      [1] (https://www.w3schools.com/python/python_intro.asp),
        [2] (https://www.geeksforgeeks.org/python/introduction-to-python/)
        Massive Ecosystem: Python comes with a "batteries-included" standard library and hundreds of thousands of third-party packages for almost any task. 
        [1] (https://www.youtube.com/watch?v=K5KVEU3aaeQ&t=1), 
        [2] (https://en.wikipedia.org/wiki/Python_(programming_language))
    """
    }

for filepath,content in sample_texts.items():
        with open(filepath, 'w',encoding='utf-8') as f:
            f.write(content)
print("Sample text file created!")
# Out:
# Sample text file created!

# %%
 ## Text loader 

from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader 

loader = TextLoader("../data/text_file/python_intro.txt",encoding='utf-8')
loader.load()
# Out:
# [Document(metadata={'source': '../data/text_file/python_intro.txt'}, page_content='python programming Introduction\n    Python is a high-level, general-purpose programming language that has become one of the most popular languages in the world due to its simplicity and readability. \n    Created by Guido van Rossum and released in 1991, Python is designed to look much like the English language, making it an ideal choice for absolute beginners. [1] (https://www.w3schools.com/python/python_intro.asp), \n    [2] (https://www.geeksforgeeks.org/python/introduction-to-python/), \n    [3] (https://en.wikipedia.org/wiki/Python_(programming_language)), \n    [4] (https://www.youtube.com/watch?v=K5KVEU3aaeQ&t=1), \n    [5] (https://www.tutorialspoint.com/python/python_overview.htm)\n    Key Features of PythonReadability: \n    Python uses clean formatting and relies on whitespace indentation instead of curly braces {} or semicolons to define blocks of code.\n      [1] (https://www.geeksforgeek
# ...

# %%
## Directory Loader 

from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_file",
    glob = "**/*.txt",    ##pattern to match files
    loader_cls = TextLoader,   ##loader class to use
    loader_kwargs = {'encoding':'utf-8'},
    show_progress=False
)

dir_loader.load()
# Out:
# [Document(metadata={'source': '..\\data\\text_file\\python_intro.txt'}, page_content='python programming Introduction\n    Python is a high-level, general-purpose programming language that has become one of the most popular languages in the world due to its simplicity and readability. \n    Created by Guido van Rossum and released in 1991, Python is designed to look much like the English language, making it an ideal choice for absolute beginners. [1] (https://www.w3schools.com/python/python_intro.asp), \n    [2] (https://www.geeksforgeeks.org/python/introduction-to-python/), \n    [3] (https://en.wikipedia.org/wiki/Python_(programming_language)), \n    [4] (https://www.youtube.com/watch?v=K5KVEU3aaeQ&t=1), \n    [5] (https://www.tutorialspoint.com/python/python_overview.htm)\n    Key Features of PythonReadability: \n    Python uses clean formatting and relies on whitespace indentation instead of curly braces {} or semicolons to define blocks of code.\n      [1] (https://www.geeksforg
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader, PyPDFLoader

dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf",    ##pattern to match files
    loader_cls = PyMuPDFLoader,   ##loader class to use
    # loader_kwargs = {'encoding':'utf-8'},
    show_progress=False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'htmldoc 1.9.15 Copyright 2011-2022 by Michael R Sweet', 'creator': '', 'creationdate': '2025-04-06T09:44:27+00:00', 'source': '..\\data\\pdf\\Abdul_Wahid_vs_The_State_Of_Rajasthan_on_28_February_2025_1.pdf', 'file_path': '..\\data\\pdf\\Abdul_Wahid_vs_The_State_Of_Rajasthan_on_28_February_2025_1.pdf', 'total_pages': 13, 'format': 'PDF 1.4', 'title': 'Abdul Wahid vs The State Of Rajasthan on 28 February, 2025', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': 'D:20250406094427Z', 'page': 0}, page_content='Abdul Wahid vs The State Of Rajasthan on 28 February, 2025\nAuthor: Pankaj Mithal\nBench: Pankaj Mithal\n2025 INSC 295\n                                                                     REPORTABLE\n                                    IN THE SUPREME COURT OF INDIA\n                                   CRIMINAL APPELLATE JURISDICTION\n                                   CRIMINAL APPEAL NO. 722 OF 
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
